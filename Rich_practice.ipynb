# %%
import pandas as pd
import scipy.stats as scts
import seaborn as sns

# %%
dw=pd.read_csv('Top_1000_wealthiest_people.csv')
dw
# Out:
#                Name Country       Industry  Net Worth (in billions)  \
# 0        Rob Walton  Mexico        Finance                     8.50
# 1       Sergey Brin     USA     Automotive                    44.76
# 2     Steve Ballmer     USA  Manufacturing                    13.43
# 3     Mukesh Ambani     USA     Technology                   120.44
# 4        Jim Walton     USA        Fashion                   122.39
# ..              ...     ...            ...                      ...
# 995  Warren Buffett     USA         Retail                   142.66
# 996  Amancio Ortega     USA          Media                   166.87
# 997    Alice Walton     USA         Retail                    30.44
# 998  Amancio Ortega   Spain         Retail                   163.18
# 999      Jim Walton     USA         Retail                   186.94
#
#                  Company
# 0                Walmart
# 1                 Google
# 2        Koch Industries
# 3                 Google
# ...

# %%
group=dw['Net Worth (in billions)']
hypothesized_mean=50
tstats,p_value=scts.ttest_1samp(group,hypothesized_mean)
alpha=0.05
print(f'Tstatistic: {tstats}')
print(f'P_value: {p_value}')
alpha=0.05
if p_value<alpha:print("reject null hypothesis")
else:print("fail to reject null hypothesis")
# Out:
# Tstatistic: 29.295562042441457
# P_value: 1.1316975465884372e-136
# reject null hypothesis
