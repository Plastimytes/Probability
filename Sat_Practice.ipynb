# %% [markdown]
# ## Probability Practice

# %% [markdown]
# ## Conditional Probability
#
# n(A);Only football players= 70% of 1000<br>
# n(B); Only basketball players= 60% of 1000<br>
# n(AnB); Both football and basketball players= 40% of 1000<br>
#
# P(A/B)=n(AnB)/n(B)<br>
# 400/600<br>
# =2/3<br>
# =0.667

# %%
## Representing this in code
nA=(70/100)*1000
nB=(60/100)*1000
n_AnB=(40/100)*1000

Prob_A_given_B=n_AnB/nB
print("Probability of Football given Basketball is",Prob_A_given_B)
# Out:
# Probability of Football given Basketball is 0.6666666666666666

# %%
# Define events A and B
event_A={1,2,3}
event_B={2,3,4}
Total=len(event_A)+len(event_B)
Total
# Probability of event A 
Prob_A=len(event_A)/Total
Prob_B=len(event_B)/Total
print("The probability of event A is", Prob_A,"and the probability of event B is", Prob_B)

Joint=len(event_A & event_B)
Conditional_Prob=Joint/len(event_B)
print("The probability of A given B is",Conditional_Prob)
# Out:
# The probability of event A is 0.5 and the probability of event B is 0.5
# The probability of A given B is 0.6666666666666666

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("diamonds_new.xlsx")
df
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53915   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53916   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53917   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53918   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53919   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53920 rows x 10 columns]

# %%
nA=df[df["cut"]=="Premium"]
len(nA)
nB=df[df["color"]=="J"]
len(nB)
Joint=df[(df["cut"]=="Premium") & (df["color"]=="J" )]# Tis filters out J colored premium diamonds
Joint_prob=len(Joint)/len(df)
print("The probability of a premium cut thats J coloured is",(Joint_prob))

#Probability of J colored
Prob_J=len(nB)/len(df)

#Conditional probability of J colored
Conditional_Prob=Joint_prob/Prob_J
print("The conditional probability of a premium cut thats J coloured is",(Conditional_Prob))
# Out:
# The probability of a premium cut thats J coloured is 0.014985163204747775
# The conditional probability of a premium cut thats J coloured is 0.28785179907374425
